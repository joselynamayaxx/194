# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats
import random
import math

# %% [markdown]
# # 1) Data Description and Curiosity Questions about the data

# %% [markdown]
# #### The dataset that was selected was the hate crime that happened during the 2016 election. This election was very controversial and caused a division in the U.S. This data is important to help determine what could happen in future elections and what are the contributing factors to hate crime.

# %% [markdown]
# ## Summary Statistics

# %%
hate_crime= pd.read_csv('hate_crimes.csv')
hate_crime.dtypes
# Out:
# state                                        object
# median_household_income                       int64
# share_unemployed_seasonal                   float64
# share_population_in_metro_areas             float64
# share_population_with_high_school_degree    float64
# share_non_citizen                           float64
# share_white_poverty                         float64
# gini_index                                  float64
# share_non_white                             float64
# share_voters_voted_trump                    float64
# hate_crimes_per_100k_splc                   float64
# avg_hatecrimes_per_100k_fbi                 float64
# dtype: object

# %% [markdown]
# ### There are 11 numerical variables and 1 categorical variable

# %%
hate_crime.head(10)
hate_crime.tail()
hate_crime.shape
# Out:
#                   state  median_household_income  share_unemployed_seasonal  \
# 0               Alabama                    42278                      0.060
# 1                Alaska                    67629                      0.064
# 2               Arizona                    49254                      0.063
# 3              Arkansas                    44922                      0.052
# 4            California                    60487                      0.059
# 5              Colorado                    60940                      0.040
# 6           Connecticut                    70161                      0.052
# 7              Delaware                    57522                      0.049
# 8  District of Columbia                    68277                      0.067
# 9               Florida                    46140                      0.052
#
#    share_population_in_metro_areas  share_population_with_high_school_degree  \
# ...

# %% [markdown]
# ### There are 51 rows and 12 columns.

# %%
hate_crime[hate_crime.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, median_household_income, share_unemployed_seasonal, share_population_in_metro_areas, share_population_with_high_school_degree, share_non_citizen, share_white_poverty, gini_index, share_non_white, share_voters_voted_trump, hate_crimes_per_100k_splc, avg_hatecrimes_per_100k_fbi]
# Index: []

# %%
hate_crime.describe()
# Out:
#        median_household_income  share_unemployed_seasonal  \
# count                51.000000                  51.000000
# mean              55223.607843                   0.049569
# std                9208.478170                   0.010698
# min               35521.000000                   0.028000
# 25%               48657.000000                   0.042000
# 50%               54916.000000                   0.051000
# 75%               60719.000000                   0.057500
# max               76165.000000                   0.073000
#
#        share_population_in_metro_areas  \
# count                        51.000000
# mean                          0.750196
# std                           0.181587
# min                           0.310000
# 25%                           0.630000
# 50%                           0.790000
# 75%                           0.895000
# max                           1.000000
#
#        share_population_with_high_school_degree  share_non_citizen  \
# ...

# %%
region = ['South','West','West','South','West','West','Northeast','South','South','South','South','West','West','Midwest','Midwest','Midwest','Midwest','South','South','Northeast','South','Northeast','Midwest','Midwest','South','Midwest','West','Midwest','West','Northeast','Northeast','West','Northeast','South','Midwest','Midwest','South','West','Northeast','Northeast','South','Midwest','South','South','West','Northeast','South','West','South','Midwest','West']
hate_crime ['Region']= region 
m_data= hate_crime 
m_data
# Out:
#                    state  median_household_income  share_unemployed_seasonal  \
# 0                Alabama                    42278                      0.060
# 1                 Alaska                    67629                      0.064
# 2                Arizona                    49254                      0.063
# 3               Arkansas                    44922                      0.052
# 4             California                    60487                      0.059
# 5               Colorado                    60940                      0.040
# 6            Connecticut                    70161                      0.052
# 7               Delaware                    57522                      0.049
# 8   District of Columbia                    68277                      0.067
# 9                Florida                    46140                      0.052
# 10               Georgia                    49555                      0.058
# ...

# %%
m_data[["hate_crimes_per_100k_splc","Region"]].groupby(["Region"]).describe()
# Out:
#           hate_crimes_per_100k_splc                                          \
#                               count      mean       std       min       25%
# Region
# Midwest                        10.0  0.279412  0.163237  0.105152  0.186071
# Northeast                       9.0  0.318545  0.201120  0.078306  0.151550
# South                          17.0  0.288994  0.333365  0.067447  0.125839
# West                           11.0  0.338041  0.239077  0.124208  0.142707
#
#
#                 50%       75%       max
# Region
# Midwest    0.210771  0.364587  0.627480
# Northeast  0.324149  0.350620  0.630811
# South      0.209894  0.324397  1.522302
# West       0.255805  0.443007  0.832850

# %% [markdown]
# #### The highest average of hate crime was in the West.

# %% [markdown]
# # 2)  Descriptive Statistics and Visualization (at least two out of the four listed below)

# %% [markdown]
# ### Distribution of Variables

# %% [markdown]
# #### Median houshold income per state

# %%
temp = stats.probplot(crime['median_household_income'],dist = "norm", plot =plt)
plt.show()

# %%
from scipy.stats import anderson

result=(anderson(crime['median_household_income'], dist='norm'))
print(f"A-D statistic: {result[0]}")
print(f"Critical values: {result[1]}")
print(f"Significance levels: {result[2]}")
# Out:
# A-D statistic: 0.15506416097549192
# Critical values: [0.539 0.614 0.736 0.859 1.022]
# Significance levels: [15.  10.   5.   2.5  1. ]

# %% [markdown]
# #### At all significance levels we fail to reject the null hypothesis, which means we don't have enough evidence to say that the sample data is not normally distributed.

# %%
from scipy.stats import shapiro

result = (shapiro(crime['median_household_income']))

print(f"S-W statistic: {result[0]}")
print(f"p-value: {result[1]}")
# Out:
# S-W statistic: 0.9900020360946655
# p-value: 0.9426988363265991

# %% [markdown]
# #### As the p-value is greater than the alpha (0.05), therefore fail to reject the null hypothesis

# %%
from scipy.stats import boxcox
m_data, _ = boxcox(crime['median_household_income'] )
ax = sns.displot(m_data, kind = "kde",color = "#e65e8e", height=10, aspect=2,
            linewidth = 5 )
ax.fig.suptitle('Distribution after YeoJohnson transfomation', size = 20)
# Out:
# Text(0.5, 0.98, 'Distribution after YeoJohnson transfomation')

# %% [markdown]
# ### Relationship between variables

# %%
crime[['share_unemployed_seasonal','share_white_poverty']].plot()
# Out:
# <AxesSubplot:>

# %%
crime[['share_unemployed_seasonal','share_non_citizen']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Both variables might have an effect on each other

# %%
crime['median_household_income'].plot(color='blue')
# Out:
# <AxesSubplot:>

# %%
crime ['hate_crimes_per_100k_splc'].hist()
# Out:
# <AxesSubplot:>

# %%
crime[['share_unemployed_seasonal','median_household_income']].hist(bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'share_unemployed_seasonal'}>,
#         <AxesSubplot:title={'center':'median_household_income'}>]],
#       dtype=object)

# %%
crime[['share_white_poverty','share_voters_voted_trump']].hist(bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'share_white_poverty'}>,
#         <AxesSubplot:title={'center':'share_voters_voted_trump'}>]],
#       dtype=object)

# %%
fig, ax = plt.subplots()
crime [['hate_crimes_per_100k_splc']].plot.kde(ax=ax, legend=False, title='Histogram: A vs. B')
crime [['hate_crimes_per_100k_splc']].plot.hist(density=True, ax=ax)
ax.set_ylabel('Probability')
ax.grid(axis='y')
ax.set_facecolor('#d8dcd6')
# Out:
# <AxesSubplot:title={'center':'Histogram: A vs. B'}, ylabel='Density'>
# <AxesSubplot:title={'center':'Histogram: A vs. B'}, ylabel='Frequency'>
# Text(0, 0.5, 'Probability')

# %% [markdown]
# ## Hypothesis Testing and Variable Correlation

# %%
crime[['hate_crimes_per_100k_splc','share_white_poverty','median_household_income','share_non_citizen','share_non_white','share_voters_voted_trump','share_population_with_high_school_degree','share_population_in_metro_areas','share_unemployed_seasonal']].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\josel\AppData\Local\Temp/ipykernel_4696/1183222633.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   crime[['hate_crimes_per_100k_splc','share_white_poverty','median_household_income','share_non_citizen','share_non_white','share_voters_voted_trump','share_population_with_high_school_degree','share_population_in_metro_areas','share_unemployed_seasonal']].corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_48b02_row0_col0, #T_48b02_row1_col1, #T_48b02_row2_col2, #T_48b02_row3_col3, #T_48b02_row4_col4, #T_48b02_row5_col5, #T_48b02_row6_col6, #T_48b02_row7_col7, #T_48b02_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_48b02_row0_col1, #T_48b02_row5_col8 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_48b02_row0_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_48b02_row0_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### H0: The hate crime rate is at least corelated with one variable
# ### H1: Hate crime is not correlated
#
# ### The variable that affects hate crime is the median household in a positive way and political standing in a significantly negative way. Therefore fail to reject the null hypothesis and at least variable presented above affects hate crime.

# %%
subsetd = crime[['hate_crimes_per_100k_splc','median_household_income','share_non_citizen','share_population_with_high_school_degree', 'share_population_in_metro_areas']]
pd.plotting.scatter_matrix(subsetd, alpha=0.9, marker="o", figsize=(15,15),diagonal = 'kde', grid=True)
# Out:
# array([[<AxesSubplot:xlabel='hate_crimes_per_100k_splc', ylabel='hate_crimes_per_100k_splc'>,
#         <AxesSubplot:xlabel='median_household_income', ylabel='hate_crimes_per_100k_splc'>,
#         <AxesSubplot:xlabel='share_non_citizen', ylabel='hate_crimes_per_100k_splc'>,
#         <AxesSubplot:xlabel='share_population_with_high_school_degree', ylabel='hate_crimes_per_100k_splc'>,
#         <AxesSubplot:xlabel='share_population_in_metro_areas', ylabel='hate_crimes_per_100k_splc'>],
#        [<AxesSubplot:xlabel='hate_crimes_per_100k_splc', ylabel='median_household_income'>,
#         <AxesSubplot:xlabel='median_household_income', ylabel='median_household_income'>,
#         <AxesSubplot:xlabel='share_non_citizen', ylabel='median_household_income'>,
#         <AxesSubplot:xlabel='share_population_with_high_school_degree', ylabel='median_household_income'>,
#         <AxesSubplot:xlabel='share_population_in_metro_areas', ylabel='median_household_income'>],
# ...

# %% [markdown]
# #### Positive correlation between median household income and non resident, high school degree and ,metro areas.

# %% [markdown]
# # Conclusion

# %% [markdown]
# #### Income inequality and political standing effect hate crime with the highest mean in the West.
